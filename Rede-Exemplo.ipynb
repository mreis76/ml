# %% [markdown]
# # **Redes Neurais e Aprendizagem Profunda**
# ---
#
#
# ## Exemplo de Treinamento de Rede Neural

# %%
from __future__ import print_function
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras import backend as K

num_classes = 10

# input image dimensions
img_rows, img_cols = 28, 28

# the data, shuffled and split between train and test sets
(x_train, y_train), (x_test, y_test) = mnist.load_data()

if K.image_data_format() == 'channels_first':
    x_train = x_train.reshape(x_train.shape[0], 1, img_rows, img_cols)
    x_test = x_test.reshape(x_test.shape[0], 1, img_rows, img_cols)
    input_shape = (1, img_rows, img_cols)
else:
    x_train = x_train.reshape(x_train.shape[0], img_rows, img_cols, 1)
    x_test = x_test.reshape(x_test.shape[0], img_rows, img_cols, 1)
    input_shape = (img_rows, img_cols, 1)

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

# convert class vectors to binary class matrices
y_train_copy = y_train
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# x_train shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples

# %%
import matplotlib.pyplot as plt

# plot first 36 images in MNIST
fig, ax = plt.subplots(6, 6, figsize = (12, 12))
#fig.suptitle('First 36 images in MNIST')
fig.tight_layout(pad = 0.3, rect = [0, 0, 0.9, 0.9])
for x, y in [(i, j) for i in range(6) for j in range(6)]:
    ax[x, y].imshow(x_train[x + y * 6].reshape((28, 28)), cmap = 'gray')
    ax[x, y].axis('off')
    ax[x, y].set_title(y_train_copy[x + y * 6])

# %%
batch_size = 128
epochs = 12

model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3),
                 activation='relu',
                 input_shape=input_shape))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=keras.optimizers.Adadelta(),
              metrics=['accuracy'])

model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(x_test, y_test))

score = model.evaluate(x_test, y_test, verbose=0)

print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Epoch 1/12
# 469/469 [==============================] - 4s 8ms/step - loss: 2.2772 - accuracy: 0.1484 - val_loss: 2.2366 - val_accuracy: 0.3100
# Epoch 2/12
# 469/469 [==============================] - 4s 8ms/step - loss: 2.2120 - accuracy: 0.2623 - val_loss: 2.1553 - val_accuracy: 0.4437
# Epoch 3/12
# 469/469 [==============================] - 4s 8ms/step - loss: 2.1285 - accuracy: 0.3682 - val_loss: 2.0492 - val_accuracy: 0.5852
# Epoch 4/12
# 469/469 [==============================] - 4s 8ms/step - loss: 2.0190 - accuracy: 0.4540 - val_loss: 1.9100 - val_accuracy: 0.6651
# Epoch 5/12
# 469/469 [==============================] - 4s 8ms/step - loss: 1.8799 - accuracy: 0.5171 - val_loss: 1.7376 - val_accuracy: 0.7178
# Epoch 6/12
# 469/469 [==============================] - 4s 8ms/step - loss: 1.7177 - accuracy: 0.5687 - val_loss: 1.5401 - val_accuracy: 0.7539
# Epoch 7/12
# 469/469 [==============================] - 4s 8ms/step - loss: 1.5495 - accuracy: 0.6023 - val_loss: 1.3418 - val_accuracy: 0.7810
# Epoch 8/12
# 469/469 [==============================] - 4s 8ms/step - loss: 1.3856 - accuracy: 0.6372 - val_loss: 1.1624 - val_accuracy: 0.7976
# Epoch 9/12
# 469/469 [==============================] - 4s 8ms/step - loss: 1.2488 - accuracy: 0.6585 - val_loss: 1.0140 - val_accuracy: 0.8103
# Epoch 10/12
# 469/469 [==============================] - 4s 8ms/step - loss: 1.1416 - accuracy: 0.6773 - val_loss: 0.8969 - val_accuracy: 0.8219
# Epoch 11/12
# 469/469 [==============================] - 4s 8ms/step - loss: 1.0508 - accuracy: 0.6959 - val_loss: 0.8060 - val_accuracy: 0.8315
# Epoch 12/12
# 469/469 [==============================] - 4s 8ms/step - loss: 0.9774 - accuracy: 0.7127 - val_loss: 0.7345 - val_accuracy: 0.8414
# Test loss: 0.7344638705253601
# Test accuracy: 0.8414000272750854
